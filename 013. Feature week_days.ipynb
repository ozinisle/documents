# %%
dataName = 'adani'
dataFrequency = '1h'
featureIndexStamp = "013_"
variation_degree=20
requiredMinimumCorrelation = .2
autoConfigFileRelativePath = '\\src\config\\autoConfig\\config.json'
KEY_preProcessedDataFilePath='preProcessedDataFilePath'

print('done')
# Out:
# done

# %%
# Include python files defined in the library folder to help facilitate the stock price Prediction 
import os
import sys  
module_path = os.path.abspath('../../'+os.path.join('.'))

sys.path.append(module_path)
print('done')

from dataPreparation import *
from dataPreprocessing import *
from utilities import *

from dataPreparation.featurePreparation import doBasicOperation
from dataPreparation.featurePreparation import doFeatureAssessment

_basicDf,_variation_degree,_preProcessedDataFilePath,_autoConfigData,_configFilePath = doBasicOperation(dataName,
       dataFrequency,autoConfigFileRelativePath,KEY_preProcessedDataFilePath,variation_degree)
# Out:
# done
# into method doBasicOperation
# jupyterNodePath >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2
# configFilePath >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\config\autoConfig\config.json
# added INPUT FEATURES >>> 4 count >>> open-high-low-close
# before return statement of method doBasicOperation

# %%
import pandas as pd

featureOfInterest = 'week_days'
_basicDf=_basicDf[1:10]
#newFeatureDf = ((_basicDf['open']+_basicDf['high'])/2).rename(featureOfInterest)
inputRawProcessedDataDF = pd.read_csv(_preProcessedDataFilePath) 
newFeatureDf = pd.to_datetime(inputRawProcessedDataDF['date-time'])
newFeatureDf = newFeatureDf.dt.weekday+1
newFeatureDf = newFeatureDf.rename(featureOfInterest)

_correlation, _reasonableCorelation ,_newTrainingSetDf ,_trainableFeaturesDf = doFeatureAssessment(newFeatureDf,
            _basicDf,_variation_degree,_preProcessedDataFilePath,_autoConfigData,
            _configFilePath,requiredMinimumCorrelation,featureIndexStamp,
            dataName,dataFrequency)

print('done')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8350/8350 [26:17<00:00,  5.23it/s]
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\rawFeatures
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\filteredFeatures
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\correlations
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\correlations\reasonableCorrelations
# cannot delete file as the file does not exist >>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\filteredFeatures\013_date-time_trainableFeaturesList.csv
# cannot delete file as the file does not exist >>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\rawFeatures\013_date-time_variations_list.csv
# cannot delete file as the file does not exist >>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\correlations\013_date-time_variations_correlation_list.csv
# cannot delete file as the file does not exist >>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\correlations\reasonableCorrelations\013_date-time_variations_reasonable_correlation_list.csv
# newTrainingSetDf shape>>>8350,140
# trainableFeaturesDf shape>>>8350,136
# done

# %%
_reasonableCorelation
# Out:
#                             open      high       low     close  date-time  \
# open                    1.000000  0.948819  0.953920  0.939676  -0.674497
# high                    0.948819  1.000000  0.930272  0.875460  -0.640817
# low                     0.953920  0.930272  1.000000  0.990151  -0.847246
# close                   0.939676  0.875460  0.990151  1.000000  -0.871707
# date-time              -0.674497 -0.640817 -0.847246 -0.871707   1.000000
# date-time_exp_1        -0.674497 -0.640817 -0.847246 -0.871707   0.843581
# date-time_exp_inv_1     0.674497  0.640817  0.847246  0.871707  -0.884923
# date-time_times_inv_2   0.674497  0.640817  0.847246  0.871707  -0.824051
# date-time_pow_2        -0.674497 -0.640817 -0.847246 -0.871707   0.980460
# date-time_pow_inv_2     0.674497  0.640817  0.847246  0.871707  -0.824051
# date-time_exp_2        -0.674497 -0.640817 -0.847246 -0.871707   0.327137
# date-time_exp_inv_2     0.674497  0.640817  0.847246  0.871707  -0.776447
# date-time_times_2      -0.674497 -0.640817 -0.847246 -0.871707   0.980460
# date-time_log_times_2  -0.674497 -0.640817 -0.847246 -0.871707   0.972898
# date-time_times_inv_3   0.674497  0.640817  0.847246  0.871707  -0.770110
# date-time_pow_3        -0.674497 -0.640817 -0.847246 -0.871707   0.940061
# date-time_pow_inv_3     0.674497  0.640817  0.847246  0.871707  -0.770110
# date-time_exp_3        -0.674497 -0.640817 -0.847246 -0.871707   0.095379
# date-time_exp_inv_3     0.674497  0.640817  0.847246  0.871707  -0.731977
# date-time_times_3      -0.674497 -0.640817 -0.847246 -0.871707   0.940061
# date-time_log_times_3  -0.674497 -0.640817 -0.847246 -0.871707   0.972898
# date-time_times_inv_4   0.674497  0.640817  0.847246  0.871707  -0.738959
# date-time_pow_4        -0.674497 -0.640817 -0.847246 -0.871707   0.894947
# date-time_pow_inv_4     0.674497  0.640817  0.847246  0.871707  -0.738959
# date-time_exp_4        -0.674497 -0.640817 -0.847246 -0.871707   0.060342
# date-time_exp_inv_4     0.674497  0.640817  0.847246  0.871707  -0.715384
# date-time_times_4      -0.674497 -0.640817 -0.847246 -0.871707   0.894947
# date-time_log_times_4  -0.674497 -0.640817 -0.847246 -0.871707   0.972898
# date-time_times_inv_5   0.674497  0.640817  0.847246  0.871707  -0.722486
# date-time_pow_5        -0.674497 -0.640817 -0.847246 -0.871707   0.848732
# ...                          ...       ...       ...       ...        ...
# date-time_times_16     -0.674497 -0.640817 -0.847246 -0.871707   0.128638
# date-time_log_times_16 -0.674497 -0.640817 -0.847246 -0.871707   0.972898
# date-time_times_inv_17  0.674497  0.640817  0.847246  0.871707  -0.705702
# date-time_pow_17       -0.674497 -0.640817 -0.847246 -0.871707   0.108465
# date-time_pow_inv_17    0.674497  0.640817  0.847246  0.871707  -0.705702
# date-time_exp_17       -0.674497 -0.640817 -0.847246 -0.871707   0.053660
# date-time_exp_inv_17    0.674497  0.640817  0.847246  0.871707  -0.705698
# date-time_times_17     -0.674497 -0.640817 -0.847246 -0.871707   0.108465
# date-time_log_times_17 -0.674497 -0.640817 -0.847246 -0.871707   0.972898
# date-time_times_inv_18  0.674497  0.640817  0.847246  0.871707  -0.705700
# date-time_pow_18       -0.674497 -0.640817 -0.847246 -0.871707   0.093815
# date-time_pow_inv_18    0.674497  0.640817  0.847246  0.871707  -0.705700
# date-time_exp_18       -0.674497 -0.640817 -0.847246 -0.871707   0.053660
# date-time_exp_inv_18    0.674497  0.640817  0.847246  0.871707  -0.705698
# date-time_times_18     -0.674497 -0.640817 -0.847246 -0.871707   0.093815
# date-time_log_times_18 -0.674497 -0.640817 -0.847246 -0.871707   0.972898
# date-time_times_inv_19  0.674497  0.640817  0.847246  0.871707  -0.705699
# date-time_pow_19       -0.674497 -0.640817 -0.847246 -0.871707   0.083185
# date-time_pow_inv_19    0.674497  0.640817  0.847246  0.871707  -0.705699
# date-time_exp_19       -0.674497 -0.640817 -0.847246 -0.871707   0.053660
# date-time_exp_inv_19    0.674497  0.640817  0.847246  0.871707  -0.705698
# date-time_times_19     -0.674497 -0.640817 -0.847246 -0.871707   0.083185
# date-time_log_times_19 -0.674497 -0.640817 -0.847246 -0.871707   0.972898
# date-time_times_inv_20  0.674497  0.640817  0.847246  0.871707  -0.705698
# date-time_pow_20       -0.674497 -0.640817 -0.847246 -0.871707   0.075465
# date-time_pow_inv_20    0.674497  0.640817  0.847246  0.871707  -0.705698
# date-time_exp_20       -0.674497 -0.640817 -0.847246 -0.871707   0.053660
# date-time_exp_inv_20    0.674497  0.640817  0.847246  0.871707  -0.705698
# date-time_times_20     -0.674497 -0.640817 -0.847246 -0.871707   0.075465
# date-time_log_times_20 -0.674497 -0.640817 -0.847246 -0.871707   0.972898
#
#                         date-time_exp_1  date-time_exp_inv_1  \
# open                          -0.674497             0.674497
# high                          -0.640817             0.640817
# low                           -0.847246             0.847246
# close                         -0.871707             0.871707
# date-time                      0.843581            -0.884923
# date-time_exp_1                1.000000            -0.567778
# date-time_exp_inv_1           -0.567778             1.000000
# date-time_times_inv_2         -0.499545             0.990300
# date-time_pow_2                0.918256            -0.780463
# date-time_pow_inv_2           -0.499545             0.990300
# date-time_exp_2                0.657634            -0.181690
# date-time_exp_inv_2           -0.442545             0.976511
# date-time_times_2              0.918256            -0.780463
# date-time_log_times_2          0.728133            -0.968484
# date-time_times_inv_3         -0.440122             0.972615
# date-time_pow_3                0.959756            -0.687965
# date-time_pow_inv_3           -0.440122             0.972615
# date-time_exp_3                0.398805            -0.039864
# date-time_exp_inv_3           -0.401295             0.956264
# date-time_times_3              0.959756            -0.687965
# date-time_log_times_3          0.728133            -0.968484
# date-time_times_inv_4         -0.409084             0.959076
# date-time_pow_4                0.982434            -0.614713
# date-time_pow_inv_4           -0.409084             0.959076
# date-time_exp_4                0.352658            -0.019791
# date-time_exp_inv_4           -0.387069             0.947351
# date-time_times_4              0.982434            -0.614713
# date-time_log_times_4          0.728133            -0.968484
# date-time_times_inv_5         -0.393710             0.950942
# date-time_pow_5                0.994039            -0.555713
# ...                                 ...                  ...
# date-time_times_16             0.442839            -0.058499
# date-time_log_times_16         0.728133            -0.968484
# date-time_times_inv_17        -0.379034             0.941817
# date-time_pow_17               0.417725            -0.046864
# date-time_pow_inv_17          -0.379034             0.941817
# date-time_exp_17               0.341732            -0.016232
# date-time_exp_inv_17          -0.379030             0.941815
# date-time_times_17             0.417725            -0.046864
# date-time_log_times_17         0.728133            -0.968484
# date-time_times_inv_18        -0.379032             0.941816
# date-time_pow_18               0.399050            -0.038477
# date-time_pow_inv_18          -0.379032             0.941816
# date-time_exp_18               0.341732            -0.016232
# date-time_exp_inv_18          -0.379030             0.941815
# date-time_times_18             0.399050            -0.038477
# date-time_log_times_18         0.728133            -0.968484
# date-time_times_inv_19        -0.379031             0.941815
# date-time_pow_19               0.385185            -0.032435
# date-time_pow_inv_19          -0.379031             0.941815
# date-time_exp_19               0.341732            -0.016232
# date-time_exp_inv_19          -0.379030             0.941815
# date-time_times_19             0.385185            -0.032435
# date-time_log_times_19         0.728133            -0.968484
# date-time_times_inv_20        -0.379031             0.941815
# date-time_pow_20               0.374880            -0.028077
# date-time_pow_inv_20          -0.379031             0.941815
# date-time_exp_20               0.341732            -0.016232
# date-time_exp_inv_20          -0.379030             0.941815
# date-time_times_20             0.374880            -0.028077
# date-time_log_times_20         0.728133            -0.968484
#
#                         date-time_times_inv_2  date-time_pow_2  \
# open                                 0.674497        -0.674497
# high                                 0.640817        -0.640817
# low                                  0.847246        -0.847246
# close                                0.871707        -0.871707
# date-time                           -0.824051         0.980460
# date-time_exp_1                     -0.499545         0.918256
# date-time_exp_inv_1                  0.990300        -0.780463
# date-time_times_inv_2                1.000000        -0.707582
# date-time_pow_2                     -0.707582         1.000000
# date-time_pow_inv_2                  1.000000        -0.707582
# date-time_exp_2                     -0.157292         0.389828
# date-time_exp_inv_2                  0.996742        -0.650912
# date-time_times_2                   -0.707582         1.000000
# date-time_log_times_2               -0.930280         0.909930
# date-time_times_inv_3                0.995433        -0.645141
# date-time_pow_3                     -0.611879         0.988230
# date-time_pow_inv_3                  0.995433        -0.645141
# date-time_exp_3                     -0.034651         0.131343
# date-time_exp_inv_3                  0.987571        -0.602549
# date-time_times_3                   -0.611879         0.988230
# date-time_log_times_3               -0.930280         0.909930
# date-time_times_inv_4                0.989079        -0.610577
# date-time_pow_4                     -0.540093         0.962537
# date-time_pow_inv_4                  0.989079        -0.610577
# date-time_exp_4                     -0.017353         0.091084
# date-time_exp_inv_4                  0.982630        -0.585091
# date-time_times_4                   -0.540093         0.962537
# date-time_log_times_4               -0.930280         0.909930
# date-time_times_inv_5                0.984679        -0.592763
# date-time_pow_5                     -0.484663         0.929208
# ...                                       ...              ...
# date-time_times_16                  -0.050687         0.169827
# date-time_log_times_16              -0.930280         0.909930
# date-time_times_inv_17               0.979370        -0.575044
# date-time_pow_17                    -0.040667         0.146785
# date-time_pow_inv_17                 0.979370        -0.575044
# date-time_exp_17                    -0.014285         0.083107
# date-time_exp_inv_17                 0.979369        -0.575040
# date-time_times_17                  -0.040667         0.146785
# date-time_log_times_17              -0.930280         0.909930
# date-time_times_inv_18               0.979370        -0.575042
# date-time_pow_18                    -0.033445         0.129989
# date-time_pow_inv_18                 0.979370        -0.575042
# date-time_exp_18                    -0.014285         0.083107
# date-time_exp_inv_18                 0.979369        -0.575040
# date-time_times_18                  -0.033445         0.129989
# date-time_log_times_18              -0.930280         0.909930
# date-time_times_inv_19               0.979369        -0.575041
# date-time_pow_19                    -0.028242         0.117756
# date-time_pow_inv_19                 0.979369        -0.575041
# date-time_exp_19                    -0.014285         0.083107
# date-time_exp_inv_19                 0.979369        -0.575039
# date-time_times_19                  -0.028242         0.117756
# date-time_log_times_19              -0.930280         0.909930
# date-time_times_inv_20               0.979369        -0.575040
# date-time_pow_20                    -0.024489         0.108839
# date-time_pow_inv_20                 0.979369        -0.575040
# date-time_exp_20                    -0.014285         0.083107
# date-time_exp_inv_20                 0.979369        -0.575039
# date-time_times_20                  -0.024489         0.108839
# date-time_log_times_20              -0.930280         0.909930
#
#                         date-time_pow_inv_2  ...  date-time_exp_inv_19  \
# open                               0.674497  ...              0.674497
# high                               0.640817  ...              0.640817
# low                                0.847246  ...              0.847246
# close                              0.871707  ...              0.871707
# date-time                         -0.824051  ...             -0.705698
# date-time_exp_1                   -0.499545  ...             -0.379030
# date-time_exp_inv_1                0.990300  ...              0.941815
# date-time_times_inv_2              1.000000  ...              0.979369
# date-time_pow_2                   -0.707582  ...             -0.575039
# date-time_pow_inv_2                1.000000  ...              0.979369
# date-time_exp_2                   -0.157292  ...             -0.113074
# date-time_exp_inv_2                0.996742  ...              0.991614
# date-time_times_2                 -0.707582  ...             -0.575039
# date-time_log_times_2             -0.930280  ...             -0.841853
# date-time_times_inv_3              0.995433  ...              0.994081
# date-time_pow_3                   -0.611879  ...             -0.477242
# date-time_pow_inv_3                0.995433  ...              0.994081
# date-time_exp_3                   -0.034651  ...             -0.023999
# date-time_exp_inv_3                0.987571  ...              0.998846
# date-time_times_3                 -0.611879  ...             -0.477242
# date-time_log_times_3             -0.930280  ...             -0.841853
# date-time_times_inv_4              0.989079  ...              0.998400
# date-time_pow_4                   -0.540093  ...             -0.409407
# date-time_pow_inv_4                0.989079  ...              0.998400
# date-time_exp_4                   -0.017353  ...             -0.011626
# date-time_exp_inv_4                0.982630  ...              0.999843
# date-time_times_4                 -0.540093  ...             -0.409407
# date-time_log_times_4             -0.930280  ...             -0.841853
# date-time_times_inv_5              0.984679  ...              0.999581
# date-time_pow_5                   -0.484663  ...             -0.360531
# ...                                     ...  ...                   ...
# date-time_times_16                -0.050687  ...             -0.035400
# date-time_log_times_16            -0.930280  ...             -0.841853
# date-time_times_inv_17             0.979370  ...              1.000000
# date-time_pow_17                  -0.040667  ...             -0.028236
# date-time_pow_inv_17               0.979370  ...              1.000000
# date-time_exp_17                  -0.014285  ...             -0.009454
# date-time_exp_inv_17               0.979369  ...              1.000000
# date-time_times_17                -0.040667  ...             -0.028236
# date-time_log_times_17            -0.930280  ...             -0.841853
# date-time_times_inv_18             0.979370  ...              1.000000
# date-time_pow_18                  -0.033445  ...             -0.023079
# date-time_pow_inv_18               0.979370  ...              1.000000
# date-time_exp_18                  -0.014285  ...             -0.009454
# date-time_exp_inv_18               0.979369  ...              1.000000
# date-time_times_18                -0.033445  ...             -0.023079
# date-time_log_times_18            -0.930280  ...             -0.841853
# date-time_times_inv_19             0.979369  ...              1.000000
# date-time_pow_19                  -0.028242  ...             -0.019367
# date-time_pow_inv_19               0.979369  ...              1.000000
# date-time_exp_19                  -0.014285  ...             -0.009454
# date-time_exp_inv_19               0.979369  ...              1.000000
# date-time_times_19                -0.028242  ...             -0.019367
# date-time_log_times_19            -0.930280  ...             -0.841853
# date-time_times_inv_20             0.979369  ...              1.000000
# date-time_pow_20                  -0.024489  ...             -0.016693
# date-time_pow_inv_20               0.979369  ...              1.000000
# date-time_exp_20                  -0.014285  ...             -0.009454
# date-time_exp_inv_20               0.979369  ...              1.000000
# date-time_times_20                -0.024489  ...             -0.016693
# date-time_log_times_20            -0.930280  ...             -0.841853
#
#                         date-time_times_19  date-time_log_times_19  \
# open                             -0.674497               -0.674497
# high                             -0.640817               -0.640817
# low                              -0.847246               -0.847246
# close                            -0.871707               -0.871707
# date-time                         0.083185                0.972898
# date-time_exp_1                   0.385185                0.728133
# date-time_exp_inv_1              -0.032435               -0.968484
# date-time_times_inv_2            -0.028242               -0.930280
# date-time_pow_2                   0.117756                0.909930
# date-time_pow_inv_2              -0.028242               -0.930280
# date-time_exp_2                   0.943735                0.259487
# date-time_exp_inv_2              -0.023108               -0.897740
# date-time_times_2                 0.117756                0.909930
# date-time_log_times_2             0.056451                1.000000
# date-time_times_inv_3            -0.023413               -0.892213
# date-time_pow_3                   0.161471                0.841468
# date-time_pow_inv_3              -0.023413               -0.892213
# date-time_exp_3                   0.999848                0.066591
# date-time_exp_inv_3              -0.020630               -0.863392
# date-time_times_3                 0.161471                0.841468
# date-time_log_times_3             0.056451                1.000000
# date-time_times_inv_4            -0.021227               -0.868551
# date-time_pow_4                   0.217556                0.779995
# date-time_pow_inv_4              -0.021227               -0.868551
# date-time_exp_4                   0.998202                0.038241
# date-time_exp_inv_4              -0.019818               -0.849897
# date-time_times_4                 0.217556                0.779995
# date-time_log_times_4             0.056451                1.000000
# date-time_times_inv_5            -0.020239               -0.855543
# date-time_pow_5                   0.289708                0.725078
# ...                                    ...                     ...
# date-time_times_16                0.997125                0.093270
# date-time_log_times_16            0.056451                1.000000
# date-time_times_inv_17           -0.019367               -0.841857
# date-time_pow_17                  0.999039                0.076886
# date-time_pow_inv_17             -0.019367               -0.841857
# date-time_exp_17                  0.996117                0.033010
# date-time_exp_inv_17             -0.019367               -0.841853
# date-time_times_17                0.999039                0.076886
# date-time_log_times_17            0.056451                1.000000
# date-time_times_inv_18           -0.019367               -0.841855
# date-time_pow_18                  0.999816                0.065028
# date-time_pow_inv_18             -0.019367               -0.841855
# date-time_exp_18                  0.996117                0.033010
# date-time_exp_inv_18             -0.019367               -0.841853
# date-time_times_18                0.999816                0.065028
# date-time_log_times_18            0.056451                1.000000
# date-time_times_inv_19           -0.019367               -0.841854
# date-time_pow_19                  1.000000                0.056451
# date-time_pow_inv_19             -0.019367               -0.841854
# date-time_exp_19                  0.996117                0.033010
# date-time_exp_inv_19             -0.019367               -0.841853
# date-time_times_19                1.000000                0.056451
# date-time_log_times_19            0.056451                1.000000
# date-time_times_inv_20           -0.019367               -0.841854
# date-time_pow_20                  0.999885                0.050241
# date-time_pow_inv_20             -0.019367               -0.841854
# date-time_exp_20                  0.996117                0.033010
# date-time_exp_inv_20             -0.019367               -0.841853
# date-time_times_20                0.999885                0.050241
# date-time_log_times_20            0.056451                1.000000
#
#                         date-time_times_inv_20  date-time_pow_20  \
# open                                  0.674497         -0.674497
# high                                  0.640817         -0.640817
# low                                   0.847246         -0.847246
# close                                 0.871707         -0.871707
# date-time                            -0.705698          0.075465
# date-time_exp_1                      -0.379031          0.374880
# date-time_exp_inv_1                   0.941815         -0.028077
# date-time_times_inv_2                 0.979369         -0.024489
# date-time_pow_2                      -0.575040          0.108839
# date-time_pow_inv_2                   0.979369         -0.024489
# date-time_exp_2                      -0.113074          0.939295
# date-time_exp_inv_2                   0.991615         -0.019920
# date-time_times_2                    -0.575040          0.108839
# date-time_log_times_2                -0.841854          0.050241
# date-time_times_inv_3                 0.994081         -0.020217
# date-time_pow_3                      -0.477243          0.151718
# date-time_pow_inv_3                   0.994081         -0.020217
# date-time_exp_3                      -0.023999          0.999638
# date-time_exp_inv_3                   0.998846         -0.017781
# date-time_times_3                    -0.477243          0.151718
# date-time_log_times_3                -0.841854          0.050241
# date-time_times_inv_4                 0.998400         -0.018304
# date-time_pow_4                      -0.409407          0.207251
# date-time_pow_inv_4                   0.998400         -0.018304
# date-time_exp_4                      -0.011626          0.998972
# date-time_exp_inv_4                   0.999843         -0.017082
# date-time_times_4                    -0.409407          0.207251
# date-time_log_times_4                -0.841854          0.050241
# date-time_times_inv_5                 0.999581         -0.017446
# date-time_pow_5                      -0.360532          0.279085
# ...                                        ...               ...
# date-time_times_16                   -0.035400          0.995885
# date-time_log_times_16               -0.841854          0.050241
# date-time_times_inv_17                1.000000         -0.016693
# date-time_pow_17                     -0.028236          0.998267
# date-time_pow_inv_17                  1.000000         -0.016693
# date-time_exp_17                     -0.009454          0.997274
# date-time_exp_inv_17                  1.000000         -0.016693
# date-time_times_17                   -0.028236          0.998267
# date-time_log_times_17               -0.841854          0.050241
# date-time_times_inv_18                1.000000         -0.016693
# date-time_pow_18                     -0.023079          0.999411
# date-time_pow_inv_18                  1.000000         -0.016693
# date-time_exp_18                     -0.009454          0.997274
# date-time_exp_inv_18                  1.000000         -0.016693
# date-time_times_18                   -0.023079          0.999411
# date-time_log_times_18               -0.841854          0.050241
# date-time_times_inv_19                1.000000         -0.016693
# date-time_pow_19                     -0.019367          0.999885
# date-time_pow_inv_19                  1.000000         -0.016693
# date-time_exp_19                     -0.009454          0.997274
# date-time_exp_inv_19                  1.000000         -0.016693
# date-time_times_19                   -0.019367          0.999885
# date-time_log_times_19               -0.841854          0.050241
# date-time_times_inv_20                1.000000         -0.016693
# date-time_pow_20                     -0.016693          1.000000
# date-time_pow_inv_20                  1.000000         -0.016693
# date-time_exp_20                     -0.009454          0.997274
# date-time_exp_inv_20                  1.000000         -0.016693
# date-time_times_20                   -0.016693          1.000000
# date-time_log_times_20               -0.841854          0.050241
#
#                         date-time_pow_inv_20  date-time_exp_20  \
# open                                0.674497         -0.674497
# high                                0.640817         -0.640817
# low                                 0.847246         -0.847246
# close                               0.871707         -0.871707
# date-time                          -0.705698          0.053660
# date-time_exp_1                    -0.379031          0.341732
# date-time_exp_inv_1                 0.941815         -0.016232
# date-time_times_inv_2               0.979369         -0.014285
# date-time_pow_2                    -0.575040          0.083107
# date-time_pow_inv_2                 0.979369         -0.014285
# date-time_exp_2                    -0.113074          0.920418
# date-time_exp_inv_2                 0.991615         -0.011288
# date-time_times_2                  -0.575040          0.083107
# date-time_log_times_2              -0.841854          0.033010
# date-time_times_inv_3               0.994081         -0.011551
# date-time_pow_3                    -0.477243          0.122874
# date-time_pow_inv_3                 0.994081         -0.011551
# date-time_exp_3                    -0.023999          0.995869
# date-time_exp_inv_3                 0.998846         -0.010071
# date-time_times_3                  -0.477243          0.122874
# date-time_log_times_3              -0.841854          0.033010
# date-time_times_inv_4               0.998400         -0.010390
# date-time_pow_4                    -0.409407          0.175914
# date-time_pow_inv_4                 0.998400         -0.010390
# date-time_exp_4                    -0.011626          0.999587
# date-time_exp_inv_4                 0.999843         -0.009674
# date-time_times_4                  -0.409407          0.175914
# date-time_log_times_4              -0.841854          0.033010
# date-time_times_inv_5               0.999581         -0.009886
# date-time_pow_5                    -0.360532          0.245760
# ...                                      ...               ...
# date-time_times_16                 -0.035400          0.987417
# date-time_log_times_16             -0.841854          0.033010
# date-time_times_inv_17              1.000000         -0.009454
# date-time_pow_17                   -0.028236          0.991688
# date-time_pow_inv_17                1.000000         -0.009454
# date-time_exp_17                   -0.009454          1.000000
# date-time_exp_inv_17                1.000000         -0.009454
# date-time_times_17                 -0.028236          0.991688
# date-time_log_times_17             -0.841854          0.033010
# date-time_times_inv_18              1.000000         -0.009454
# date-time_pow_18                   -0.023079          0.994377
# date-time_pow_inv_18                1.000000         -0.009454
# date-time_exp_18                   -0.009454          1.000000
# date-time_exp_inv_18                1.000000         -0.009454
# date-time_times_18                 -0.023079          0.994377
# date-time_log_times_18             -0.841854          0.033010
# date-time_times_inv_19              1.000000         -0.009454
# date-time_pow_19                   -0.019367          0.996117
# date-time_pow_inv_19                1.000000         -0.009454
# date-time_exp_19                   -0.009454          1.000000
# date-time_exp_inv_19                1.000000         -0.009454
# date-time_times_19                 -0.019367          0.996117
# date-time_log_times_19             -0.841854          0.033010
# date-time_times_inv_20              1.000000         -0.009454
# date-time_pow_20                   -0.016693          0.997274
# date-time_pow_inv_20                1.000000         -0.009454
# date-time_exp_20                   -0.009454          1.000000
# date-time_exp_inv_20                1.000000         -0.009454
# date-time_times_20                 -0.016693          0.997274
# date-time_log_times_20             -0.841854          0.033010
#
#                         date-time_exp_inv_20  date-time_times_20  \
# open                                0.674497           -0.674497
# high                                0.640817           -0.640817
# low                                 0.847246           -0.847246
# close                               0.871707           -0.871707
# date-time                          -0.705698            0.075465
# date-time_exp_1                    -0.379030            0.374880
# date-time_exp_inv_1                 0.941815           -0.028077
# date-time_times_inv_2               0.979369           -0.024489
# date-time_pow_2                    -0.575039            0.108839
# date-time_pow_inv_2                 0.979369           -0.024489
# date-time_exp_2                    -0.113074            0.939295
# date-time_exp_inv_2                 0.991614           -0.019920
# date-time_times_2                  -0.575039            0.108839
# date-time_log_times_2              -0.841853            0.050241
# date-time_times_inv_3               0.994081           -0.020217
# date-time_pow_3                    -0.477242            0.151718
# date-time_pow_inv_3                 0.994081           -0.020217
# date-time_exp_3                    -0.023999            0.999638
# date-time_exp_inv_3                 0.998846           -0.017781
# date-time_times_3                  -0.477242            0.151718
# date-time_log_times_3              -0.841853            0.050241
# date-time_times_inv_4               0.998400           -0.018304
# date-time_pow_4                    -0.409407            0.207251
# date-time_pow_inv_4                 0.998400           -0.018304
# date-time_exp_4                    -0.011626            0.998972
# date-time_exp_inv_4                 0.999843           -0.017082
# date-time_times_4                  -0.409407            0.207251
# date-time_log_times_4              -0.841853            0.050241
# date-time_times_inv_5               0.999581           -0.017446
# date-time_pow_5                    -0.360531            0.279085
# ...                                      ...                 ...
# date-time_times_16                 -0.035400            0.995885
# date-time_log_times_16             -0.841853            0.050241
# date-time_times_inv_17              1.000000           -0.016693
# date-time_pow_17                   -0.028236            0.998267
# date-time_pow_inv_17                1.000000           -0.016693
# date-time_exp_17                   -0.009454            0.997274
# date-time_exp_inv_17                1.000000           -0.016693
# date-time_times_17                 -0.028236            0.998267
# date-time_log_times_17             -0.841853            0.050241
# date-time_times_inv_18              1.000000           -0.016693
# date-time_pow_18                   -0.023079            0.999411
# date-time_pow_inv_18                1.000000           -0.016693
# date-time_exp_18                   -0.009454            0.997274
# date-time_exp_inv_18                1.000000           -0.016693
# date-time_times_18                 -0.023079            0.999411
# date-time_log_times_18             -0.841853            0.050241
# date-time_times_inv_19              1.000000           -0.016693
# date-time_pow_19                   -0.019367            0.999885
# date-time_pow_inv_19                1.000000           -0.016693
# date-time_exp_19                   -0.009454            0.997274
# date-time_exp_inv_19                1.000000           -0.016693
# date-time_times_19                 -0.019367            0.999885
# date-time_log_times_19             -0.841853            0.050241
# date-time_times_inv_20              1.000000           -0.016693
# date-time_pow_20                   -0.016693            1.000000
# date-time_pow_inv_20                1.000000           -0.016693
# date-time_exp_20                   -0.009454            0.997274
# date-time_exp_inv_20                1.000000           -0.016693
# date-time_times_20                 -0.016693            1.000000
# date-time_log_times_20             -0.841853            0.050241
#
#                         date-time_log_times_20
# open                                 -0.674497
# high                                 -0.640817
# low                                  -0.847246
# close                                -0.871707
# date-time                             0.972898
# date-time_exp_1                       0.728133
# date-time_exp_inv_1                  -0.968484
# date-time_times_inv_2                -0.930280
# date-time_pow_2                       0.909930
# date-time_pow_inv_2                  -0.930280
# date-time_exp_2                       0.259487
# date-time_exp_inv_2                  -0.897740
# date-time_times_2                     0.909930
# date-time_log_times_2                 1.000000
# date-time_times_inv_3                -0.892213
# date-time_pow_3                       0.841468
# date-time_pow_inv_3                  -0.892213
# date-time_exp_3                       0.066591
# date-time_exp_inv_3                  -0.863392
# date-time_times_3                     0.841468
# date-time_log_times_3                 1.000000
# date-time_times_inv_4                -0.868551
# date-time_pow_4                       0.779995
# date-time_pow_inv_4                  -0.868551
# date-time_exp_4                       0.038241
# date-time_exp_inv_4                  -0.849897
# date-time_times_4                     0.779995
# date-time_log_times_4                 1.000000
# date-time_times_inv_5                -0.855543
# date-time_pow_5                       0.725078
# ...                                        ...
# date-time_times_16                    0.093270
# date-time_log_times_16                1.000000
# date-time_times_inv_17               -0.841857
# date-time_pow_17                      0.076886
# date-time_pow_inv_17                 -0.841857
# date-time_exp_17                      0.033010
# date-time_exp_inv_17                 -0.841853
# date-time_times_17                    0.076886
# date-time_log_times_17                1.000000
# date-time_times_inv_18               -0.841855
# date-time_pow_18                      0.065028
# date-time_pow_inv_18                 -0.841855
# date-time_exp_18                      0.033010
# date-time_exp_inv_18                 -0.841853
# date-time_times_18                    0.065028
# date-time_log_times_18                1.000000
# date-time_times_inv_19               -0.841854
# date-time_pow_19                      0.056451
# date-time_pow_inv_19                 -0.841854
# date-time_exp_19                      0.033010
# date-time_exp_inv_19                 -0.841853
# date-time_times_19                    0.056451
# date-time_log_times_19                1.000000
# date-time_times_inv_20               -0.841854
# date-time_pow_20                      0.050241
# date-time_pow_inv_20                 -0.841854
# date-time_exp_20                      0.033010
# date-time_exp_inv_20                 -0.841853
# date-time_times_20                    0.050241
# date-time_log_times_20                1.000000
#
# [140 rows x 140 columns]
